# %%
import wikipedia as wp #
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from geopy.geocoders import Nominatim #geocoding library


import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans 

import folium # map rendering library
import time
import logging


   
#Get the html source for wikipedia containging table to clean
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df = pd.read_html(html)[0]
df.to_csv('beautifulsoup_pandas.csv',header=0,index=False)
new_header = df.iloc[0] #grab the first row for the header
df = df[1:] #take the data less the header row
df.columns = new_header #set the header row as the df header
df = df[df.Borough !='Not assigned'] #drop rows if Borough is not assigned
df['Neighbourhood'] = np.where(df['Neighbourhood'] == 'Not assigned', df['Borough'], df['Neighbourhood']) #assign Borough to Neighbourhood, if Neighbourhood is not assigned
df= df.groupby(['Postcode','Borough'])['Neighbourhood'].apply(','.join).reset_index() #combining postcode with same value into single row
print(df.shape)
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df['Borough'].unique()),
        df.shape[0]
    )
)

#Following part of code is to get Latitide and Longitude coordinates for Neighbourhoods
PostCode_series = df['Postcode'].copy()
Borough_series=df['Borough'].copy()
neighborhoods_series=df['Neighbourhood'].copy()
addresses=(neighborhoods_series+','+Borough_series+ ',Toronto,Ontario,'+PostCode_series)#concatenated series of addresses

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)
BACKOFF_TIME = 30
API_KEY='AIzaSyBB4VEIERWf0tlL_nPG7ybvUkc8ED28kDo'
RETURN_FULL_RESULTS = False
def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Setting up Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

#------------------ PROCESSING LOOP -----------------------------

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
# All done
logger.info("Finished geocoding all addresses")
results=pd.DataFrame(results)
df["latitude"]=results["latitude"]#storing corresponding latitude to main dataframe
df["longitude"]=results["longitude"]#storing corresponding longitude to main dataframe
print(df)
# Out:
# (103, 3)
# The dataframe has 11 boroughs and 103 neighborhoods.
# Geocoded: Rouge,Malvern,Scarborough,Toronto,Ontario,M1B: OK
# Geocoded: Highland Creek,Rouge Hill,Port Union,Scarborough,Toronto,Ontario,M1C: OK
# Geocoded: Guildwood,Morningside,West Hill,Scarborough,Toronto,Ontario,M1E: OK
# Geocoded: Woburn,Scarborough,Toronto,Ontario,M1G: OK
# Geocoded: Cedarbrae,Scarborough,Toronto,Ontario,M1H: OK
# Geocoded: Scarborough Village,Scarborough,Toronto,Ontario,M1J: OK
# Geocoded: East Birchmount Park,Ionview,Kennedy Park,Scarborough,Toronto,Ontario,M1K: OK
# Geocoded: Clairlea,Golden Mile,Oakridge,Scarborough,Toronto,Ontario,M1L: OK
# Geocoded: Cliffcrest,Cliffside,Scarborough Village West,Scarborough,Toronto,Ontario,M1M: OK
# Geocoded: Birch Cliff,Cliffside West,Scarborough,Toronto,Ontario,M1N: OK
# Geocoded: Dorset Park,Scarborough Town Centre,Wexford Heights,Scarborough,Toronto,Ontario,M1P: OK
# Geocoded: Maryvale,Wexford,Scarborough,Toronto,Ontario,M1R: OK
# Geocoded: Agincourt,Scarborough,Toronto,Ontario,M1S: OK
# Geocoded: Clarks Corners,Sullivan,Tam O'Shanter,Scarborough,Toronto,Ontario,M1T: OK
# Geocoded: Agincourt North,L'Amoreaux East,Milliken,Steeles East,Scarborough,Toronto,Ontario,M1V: OK
# Geocoded: L'Amoreaux West,Scarborough,Toronto,Ontario,M1W: OK
# Geocoded: Upper Rouge,Scarborough,Toronto,Ontario,M1X: OK
# Geocoded: Hillcrest Village,North York,Toronto,Ontario,M2H: OK
# Geocoded: Fairview,Henry Farm,Oriole,North York,Toronto,Ontario,M2J: OK
# Geocoded: Bayview Village,North York,Toronto,Ontario,M2K: OK
# Geocoded: Silver Hills,York Mills,North York,Toronto,Ontario,M2L: OK
# Geocoded: Newtonbrook,Willowdale,North York,Toronto,Ontario,M2M: OK
# Geocoded: Willowdale South,North York,Toronto,Ontario,M2N: OK
# Geocoded: York Mills West,North York,Toronto,Ontario,M2P: OK
# Geocoded: Willowdale West,North York,Toronto,Ontario,M2R: OK
# Geocoded: Parkwoods,North York,Toronto,Ontario,M3A: OK
# Geocoded: Don Mills North,North York,Toronto,Ontario,M3B: OK
# Geocoded: Flemingdon Park,Don Mills South,North York,Toronto,Ontario,M3C: OK
# Geocoded: Bathurst Manor,Downsview North,Wilson Heights,North York,Toronto,Ontario,M3H: OK
# Geocoded: Northwood Park,York University,North York,Toronto,Ontario,M3J: OK
# Geocoded: CFB Toronto,Downsview East,North York,Toronto,Ontario,M3K: OK
# Geocoded: Downsview West,North York,Toronto,Ontario,M3L: OK
# Geocoded: Downsview Central,North York,Toronto,Ontario,M3M: OK
# Geocoded: Downsview Northwest,North York,Toronto,Ontario,M3N: OK
# Geocoded: Victoria Village,North York,Toronto,Ontario,M4A: OK
# Geocoded: Woodbine Gardens,Parkview Hill,East York,Toronto,Ontario,M4B: OK
# Geocoded: Woodbine Heights,East York,Toronto,Ontario,M4C: OK
# Geocoded: The Beaches,East Toronto,Toronto,Ontario,M4E: OK
# Geocoded: Leaside,East York,Toronto,Ontario,M4G: OK
# Geocoded: Thorncliffe Park,East York,Toronto,Ontario,M4H: OK
# Geocoded: East Toronto,East York,Toronto,Ontario,M4J: OK
# Geocoded: The Danforth West,Riverdale,East Toronto,Toronto,Ontario,M4K: OK
# Geocoded: The Beaches West,India Bazaar,East Toronto,Toronto,Ontario,M4L: OK
# Geocoded: Studio District,East Toronto,Toronto,Ontario,M4M: OK
# Geocoded: Lawrence Park,Central Toronto,Toronto,Ontario,M4N: OK
# Geocoded: Davisville North,Central Toronto,Toronto,Ontario,M4P: OK
# Geocoded: North Toronto West,Central Toronto,Toronto,Ontario,M4R: OK
# Geocoded: Davisville,Central Toronto,Toronto,Ontario,M4S: OK
# Geocoded: Moore Park,Summerhill East,Central Toronto,Toronto,Ontario,M4T: OK
# Geocoded: Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West,Central Toronto,Toronto,Ontario,M4V: OK
# Geocoded: Rosedale,Downtown Toronto,Toronto,Ontario,M4W: OK
# Geocoded: Cabbagetown,St. James Town,Downtown Toronto,Toronto,Ontario,M4X: OK
# Geocoded: Church and Wellesley,Downtown Toronto,Toronto,Ontario,M4Y: OK
# Geocoded: Harbourfront,Regent Park,Downtown Toronto,Toronto,Ontario,M5A: OK
# Geocoded: Ryerson,Garden District,Downtown Toronto,Toronto,Ontario,M5B: OK
# Geocoded: St. James Town,Downtown Toronto,Toronto,Ontario,M5C: OK
# Geocoded: Berczy Park,Downtown Toronto,Toronto,Ontario,M5E: OK
# Geocoded: Central Bay Street,Downtown Toronto,Toronto,Ontario,M5G: OK
# Geocoded: Adelaide,King,Richmond,Downtown Toronto,Toronto,Ontario,M5H: OK
# Geocoded: Harbourfront East,Toronto Islands,Union Station,Downtown Toronto,Toronto,Ontario,M5J: OK
# Geocoded: Design Exchange,Toronto Dominion Centre,Downtown Toronto,Toronto,Ontario,M5K: OK
# Geocoded: Commerce Court,Victoria Hotel,Downtown Toronto,Toronto,Ontario,M5L: OK
# Geocoded: Bedford Park,Lawrence Manor East,North York,Toronto,Ontario,M5M: OK
# Geocoded: Roselawn,Central Toronto,Toronto,Ontario,M5N: OK
# Geocoded: Forest Hill North,Forest Hill West,Central Toronto,Toronto,Ontario,M5P: OK
# Geocoded: The Annex,North Midtown,Yorkville,Central Toronto,Toronto,Ontario,M5R: OK
# Geocoded: Harbord,University of Toronto,Downtown Toronto,Toronto,Ontario,M5S: OK
# Geocoded: Chinatown,Grange Park,Kensington Market,Downtown Toronto,Toronto,Ontario,M5T: OK
# Geocoded: CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara,Downtown Toronto,Toronto,Ontario,M5V: OK
# Geocoded: Stn A PO Boxes 25 The Esplanade,Downtown Toronto,Toronto,Ontario,M5W: OK
# Geocoded: First Canadian Place,Underground city,Downtown Toronto,Toronto,Ontario,M5X: OK
# Geocoded: Lawrence Heights,Lawrence Manor,North York,Toronto,Ontario,M6A: OK
# Geocoded: Glencairn,North York,Toronto,Ontario,M6B: OK
# Geocoded: Humewood-Cedarvale,York,Toronto,Ontario,M6C: OK
# Geocoded: Caledonia-Fairbanks,York,Toronto,Ontario,M6E: OK
# Geocoded: Christie,Downtown Toronto,Toronto,Ontario,M6G: OK
# Geocoded: Dovercourt Village,Dufferin,West Toronto,Toronto,Ontario,M6H: OK
# Geocoded: Little Portugal,Trinity,West Toronto,Toronto,Ontario,M6J: OK
# Geocoded: Brockton,Exhibition Place,Parkdale Village,West Toronto,Toronto,Ontario,M6K: OK
# Geocoded: Downsview,North Park,Upwood Park,North York,Toronto,Ontario,M6L: OK
# Geocoded: Del Ray,Keelesdale,Mount Dennis,Silverthorn,York,Toronto,Ontario,M6M: OK
# Geocoded: The Junction North,Runnymede,York,Toronto,Ontario,M6N: OK
# Geocoded: High Park,The Junction South,West Toronto,Toronto,Ontario,M6P: OK
# Geocoded: Parkdale,Roncesvalles,West Toronto,Toronto,Ontario,M6R: OK
# Geocoded: Runnymede,Swansea,West Toronto,Toronto,Ontario,M6S: OK
# Geocoded: Queen's Park,Queen's Park,Toronto,Ontario,M7A: OK
# Geocoded: Canada Post Gateway Processing Centre,Mississauga,Toronto,Ontario,M7R: OK
# Geocoded: Business Reply Mail Processing Centre 969 Eastern,East Toronto,Toronto,Ontario,M7Y: OK
# Geocoded: Humber Bay Shores,Mimico South,New Toronto,Etobicoke,Toronto,Ontario,M8V: OK
# Geocoded: Alderwood,Long Branch,Etobicoke,Toronto,Ontario,M8W: OK
# Geocoded: The Kingsway,Montgomery Road,Old Mill North,Etobicoke,Toronto,Ontario,M8X: OK
# Geocoded: Humber Bay,King's Mill Park,Kingsway Park South East,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea,Etobicoke,Toronto,Ontario,M8Y: OK
# Geocoded: Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor,Etobicoke,Toronto,Ontario,M8Z: OK
# Geocoded: Islington Avenue,Etobicoke,Toronto,Ontario,M9A: OK
# Geocoded: Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park,Etobicoke,Toronto,Ontario,M9B: OK
# Geocoded: Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe,Etobicoke,Toronto,Ontario,M9C: OK
# Geocoded: Humber Summit,North York,Toronto,Ontario,M9L: OK
# Geocoded: Emery,Humberlea,North York,Toronto,Ontario,M9M: OK
# Geocoded: Weston,York,Toronto,Ontario,M9N: OK
# Geocoded: Westmount,Etobicoke,Toronto,Ontario,M9P: OK
# Completed 100 of 103 address
# Geocoded: Kingsview Village,Martin Grove Gardens,Richview Gardens,St. Phillips,Etobicoke,Toronto,Ontario,M9R: OK
# Geocoded: Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown,Etobicoke,Toronto,Ontario,M9V: OK
# Geocoded: Northwest,Etobicoke,Toronto,Ontario,M9W: OK
# Finished geocoding all addresses
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# 29       M3J        North York
# 30       M3K        North York
# 31       M3L        North York
# 32       M3M        North York
# 33       M3N        North York
# 34       M4A        North York
# 35       M4B         East York
# 36       M4C         East York
# 37       M4E      East Toronto
# 38       M4G         East York
# 39       M4H         East York
# 40       M4J         East York
# 41       M4K      East Toronto
# 42       M4L      East Toronto
# 43       M4M      East Toronto
# 44       M4N   Central Toronto
# 45       M4P   Central Toronto
# 46       M4R   Central Toronto
# 47       M4S   Central Toronto
# 48       M4T   Central Toronto
# 49       M4V   Central Toronto
# 50       M4W  Downtown Toronto
# 51       M4X  Downtown Toronto
# 52       M4Y  Downtown Toronto
# 53       M5A  Downtown Toronto
# 54       M5B  Downtown Toronto
# 55       M5C  Downtown Toronto
# 56       M5E  Downtown Toronto
# 57       M5G  Downtown Toronto
# 58       M5H  Downtown Toronto
# 59       M5J  Downtown Toronto
# 60       M5K  Downtown Toronto
# 61       M5L  Downtown Toronto
# 62       M5M        North York
# 63       M5N   Central Toronto
# 64       M5P   Central Toronto
# 65       M5R   Central Toronto
# 66       M5S  Downtown Toronto
# 67       M5T  Downtown Toronto
# 68       M5V  Downtown Toronto
# 69       M5W  Downtown Toronto
# 70       M5X  Downtown Toronto
# 71       M6A        North York
# 72       M6B        North York
# 73       M6C              York
# 74       M6E              York
# 75       M6G  Downtown Toronto
# 76       M6H      West Toronto
# 77       M6J      West Toronto
# 78       M6K      West Toronto
# 79       M6L        North York
# 80       M6M              York
# 81       M6N              York
# 82       M6P      West Toronto
# 83       M6R      West Toronto
# 84       M6S      West Toronto
# 85       M7A      Queen's Park
# 86       M7R       Mississauga
# 87       M7Y      East Toronto
# 88       M8V         Etobicoke
# 89       M8W         Etobicoke
# 90       M8X         Etobicoke
# 91       M8Y         Etobicoke
# 92       M8Z         Etobicoke
# 93       M9A         Etobicoke
# 94       M9B         Etobicoke
# 95       M9C         Etobicoke
# 96       M9L        North York
# 97       M9M        North York
# 98       M9N              York
# 99       M9P         Etobicoke
# 100      M9R         Etobicoke
# 101      M9V         Etobicoke
# 102      M9W         Etobicoke
#
#                                          Neighbourhood   latitude  longitude
# 0                                        Rouge,Malvern  43.806686 -79.194353
# 1                 Highland Creek,Rouge Hill,Port Union  43.780707 -79.130264
# 2                      Guildwood,Morningside,West Hill  43.753240 -79.179809
# 3                                               Woburn  43.770992 -79.216917
# 4                                            Cedarbrae  43.773136 -79.239476
# 5                                  Scarborough Village  43.744734 -79.239476
# 6            East Birchmount Park,Ionview,Kennedy Park  43.730517 -79.277170
# 7                        Clairlea,Golden Mile,Oakridge  43.721848 -79.288887
# 8        Cliffcrest,Cliffside,Scarborough Village West  43.716316 -79.239476
# 9                           Birch Cliff,Cliffside West  43.702314 -79.250164
# 10   Dorset Park,Scarborough Town Centre,Wexford He...  43.765831 -79.281111
# 11                                    Maryvale,Wexford  43.762575 -79.314767
# 12                                           Agincourt  43.794200 -79.262029
# 13               Clarks Corners,Sullivan,Tam O'Shanter  43.786093 -79.299740
# 14   Agincourt North,L'Amoreaux East,Milliken,Steel...  43.820085 -79.322883
# 15                                     L'Amoreaux West  43.799586 -79.310051
# 16                                         Upper Rouge  43.809571 -79.187170
# 17                                   Hillcrest Village  43.803762 -79.363452
# 18                          Fairview,Henry Farm,Oriole  43.781847 -79.351077
# 19                                     Bayview Village  43.769181 -79.385447
# 20                             Silver Hills,York Mills  43.763013 -79.370491
# 21                              Newtonbrook,Willowdale  43.789053 -79.408493
# 22                                    Willowdale South  43.770120 -79.408493
# 23                                     York Mills West  43.752758 -79.400049
# 24                                     Willowdale West  43.782736 -79.442259
# 25                                           Parkwoods  43.753259 -79.329656
# 26                                     Don Mills North  43.745906 -79.352188
# 27                     Flemingdon Park,Don Mills South  43.718373 -79.331390
# 28       Bathurst Manor,Downsview North,Wilson Heights  43.755311 -79.459892
# 29                      Northwood Park,York University  43.773454 -79.501868
# 30                          CFB Toronto,Downsview East  43.726124 -79.479646
# 31                                      Downsview West  43.719553 -79.513660
# 32                                   Downsview Central  43.728496 -79.495697
# 33                                 Downsview Northwest  43.756887 -79.528779
# 34                                    Victoria Village  43.725882 -79.315572
# 35                      Woodbine Gardens,Parkview Hill  43.706139 -79.325415
# 36                                    Woodbine Heights  43.693328 -79.316064
# 37                                         The Beaches  43.676357 -79.293031
# 38                                             Leaside  43.709060 -79.363452
# 39                                    Thorncliffe Park  43.705369 -79.349372
# 40                                        East Toronto  43.682412 -79.328787
# 41                         The Danforth West,Riverdale  43.679557 -79.352188
# 42                       The Beaches West,India Bazaar  43.672341 -79.322543
# 43                                     Studio District  43.658395 -79.338965
# 44                                       Lawrence Park  43.723282 -79.388790
# 45                                    Davisville North  43.706573 -79.397816
# 46                                  North Toronto West  43.706029 -79.402510
# 47                                          Davisville  43.696974 -79.395839
# 48                          Moore Park,Summerhill East  43.689574 -79.383160
# 49   Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.704318 -79.426784
# 50                                            Rosedale  43.679563 -79.377529
# 51                          Cabbagetown,St. James Town  43.665722 -79.368700
# 52                                Church and Wellesley  43.665860 -79.383160
# 53                            Harbourfront,Regent Park  43.638834 -79.381878
# 54                             Ryerson,Garden District  43.657658 -79.378802
# 55                                      St. James Town  43.668195 -79.373771
# 56                                         Berczy Park  43.647985 -79.375225
# 57                                  Central Bay Street  43.656088 -79.383860
# 58                              Adelaide,King,Richmond  43.649972 -79.383223
# 59     Harbourfront East,Toronto Islands,Union Station  43.645207 -79.380588
# 60             Design Exchange,Toronto Dominion Centre  43.647694 -79.380328
# 61                       Commerce Court,Victoria Hotel  43.648172 -79.379518
# 62                    Bedford Park,Lawrence Manor East  43.724559 -79.416464
# 63                                            Roselawn  43.705142 -79.424894
# 64                  Forest Hill North,Forest Hill West  43.696948 -79.411307
# 65                   The Annex,North Midtown,Yorkville  43.672506 -79.395972
# 66                       Harbord,University of Toronto  43.662892 -79.395656
# 67             Chinatown,Grange Park,Kensington Market  43.654842 -79.398522
# 68   CN Tower,Bathurst Quay,Island airport,Harbourf...  43.642566 -79.387057
# 69                     Stn A PO Boxes 25 The Esplanade  43.646155 -79.375022
# 70               First Canadian Place,Underground city  43.648636 -79.381744
# 71                     Lawrence Heights,Lawrence Manor  43.722774 -79.450928
# 72                                           Glencairn  43.709986 -79.438344
# 73                                  Humewood-Cedarvale  43.693781 -79.428191
# 74                                 Caledonia-Fairbanks  43.686916 -79.456325
# 75                                            Christie  43.664109 -79.418359
# 76                         Dovercourt Village,Dufferin  43.660123 -79.434717
# 77                             Little Portugal,Trinity  43.647927 -79.419750
# 78          Brockton,Exhibition Place,Parkdale Village  43.653191 -79.438039
# 79                    Downsview,North Park,Upwood Park  43.708633 -79.502524
# 80         Del Ray,Keelesdale,Mount Dennis,Silverthorn  43.713325 -79.428653
# 81                        The Junction North,Runnymede  43.665260 -79.481982
# 82                        High Park,The Junction South  43.665646 -79.476405
# 83                               Parkdale,Roncesvalles  43.642825 -79.447703
# 84                                   Runnymede,Swansea  43.650023 -79.482551
# 85                                        Queen's Park  43.664366 -79.392328
# 86               Canada Post Gateway Processing Centre  43.636294 -79.615651
# 87   Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
# 88          Humber Bay Shores,Mimico South,New Toronto  43.631647 -79.472653
# 89                               Alderwood,Long Branch  43.601636 -79.547238
# 90         The Kingsway,Montgomery Road,Old Mill North  43.650903 -79.492837
# 91   Humber Bay,King's Mill Park,Kingsway Park Sout...  43.651419 -79.513129
# 92   Kingsway Park South West,Mimico NW,The Queensw...  43.644123 -79.525614
# 93                                    Islington Avenue  43.682467 -79.540162
# 94   Cloverdale,Islington,Martin Grove,Princess Gar...  43.631647 -79.555659
# 95   Bloordale Gardens,Eringate,Markland Wood,Old B...  43.643238 -79.580168
# 96                                       Humber Summit  43.756303 -79.565963
# 97                                     Emery,Humberlea  43.748514 -79.538591
# 98                                              Weston  43.706876 -79.518188
# 99                                           Westmount  43.687111 -79.522405
# 100  Kingsview Village,Martin Grove Gardens,Richvie...  43.697409 -79.557804
# 101  Albion Gardens,Beaumond Heights,Humbergate,Jam...  43.728368 -79.591509
# 102                                          Northwest  43.706748 -79.594054
